# %%
import numpy as np
import pandas as pd
import pickle

# %% [markdown]
# # Output of 50x1000 $unit^2$, 100 sensors, uniform distribution Dataset

# %%
df = pd.read_csv('Results/uniform/50x1000unit/100sensors/First_vs_Last_solutions.csv')
df = df.drop(columns=df.columns[0])

# %%
df
# Out:
#     Dataset No.  Run No.  Power weight  Num. weight  Dist. weight
# 0           0.0      0.0           0.1          0.1           0.8  \
# 1           0.0      0.0           0.2          0.1           0.7
# 2           0.0      0.0           0.5          0.1           0.4
# 3           0.0      0.0           0.6          0.1           0.3
# 4           0.0      0.0           0.7          0.1           0.2
# ..          ...      ...           ...          ...           ...
# 95          0.0      4.0           0.5          0.4           0.1
# 96          0.0      4.0           0.1          0.5           0.4
# 97          0.0      4.0           0.1          0.6           0.3
# 98          0.0      4.0           0.1          0.7           0.2
# 99          0.0      4.0           0.1          0.8           0.1
#
#      Power_first  Num. Active Sensors_first  Avg. Dist. to Sink node_first
# 0   18706.313334                       28.0                     294.904777  \
# ...

# %% [markdown]
# # Specific Output of Dataset and Runtime

# %% [markdown]
# ### Choose Dataset and Runtime

# %%
DatasetNo = 0
RuntimeNo = 0

# %% [markdown]
# ### Visualize Data

# %%
with open(f'Datasets/uniform/50x1000unit/100sensors/sensors_positions_0.pickle','rb') as file:
    sensors_positions = pickle.load(file)
with open('Datasets/sink_nodes_positions.pickle','rb') as file:
    sink_nodes_positions = pickle.load(file)
with open('Results/uniform/50x1000unit/100sensors/dataset_0/first_solutions_0.pickle','rb') as file:
    sol = pickle.load(file)

# %%
import Plot

# %%
Plot.Plot_position(sensors_positions, sink_nodes_positions)

# %% [markdown]
# ### View Output

# %%
for i in range(20):
    Plot.Plot_solution(sensors_positions,sol[i])

# %%
df.columns
# Out:
# Index(['Dataset No.', 'Run No.', 'Power weight', 'Num. weight', 'Dist. weight',
#        'Power_first', 'Num. Active Sensors_first',
#        'Avg. Dist. to Sink node_first', 'Power_last',
#        'Num. Active Sensors_last', 'Avg. Dist. to Sink node_last'],
#       dtype='object')

# %%
df.loc[(df['Dataset No.']==0) & (df['Run No.']==0)][['Power weight','Num. weight','Dist. weight','Power_first','Power_last','Num. Active Sensors_first','Num. Active Sensors_last','Avg. Dist. to Sink node_first','Avg. Dist. to Sink node_last']]
# Out:
#     Power weight  Num. weight  Dist. weight   Power_first    Power_last
# 0            0.1          0.1           0.8  18706.313334  17376.060299  \
# 1            0.2          0.1           0.7  24660.263356  10652.013480
# 2            0.5          0.1           0.4  18799.453366  14323.922816
# 3            0.6          0.1           0.3  15813.618835  11046.273628
# 4            0.7          0.1           0.2  15442.032456  11046.273628
# 5            0.8          0.1           0.1  19272.976185  11767.283728
# 6            0.1          0.2           0.7  25073.830408  16337.988237
# 7            0.2          0.2           0.6  16017.643490  10652.013480
# 8            0.5          0.2           0.3  17930.833423  10619.715503
# 9            0.6          0.2           0.2  19820.347098  10619.715503
# 10           0.7          0.2           0.1  19220.800495  10628.699658
# 11           0.1          0.3           0.6  17928.797191  14191.182678
# ...

# %%
Plot.Plot_fitness(100,5)
Plot.Plot_fitness(100,5,'pop_avg_fitness')

# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np

datasets = [3,4]
POP_SIZE = 20

df = pd.read_csv("Results/uniform/50x1000unit/100sensors/First_vs_Last_solutions.csv")
sets = len(df) / len(datasets) / POP_SIZE
sets = int(sets)

f1 = np.zeros((POP_SIZE,sets))
f2 = np.zeros((POP_SIZE,sets))
f3 = np.zeros((POP_SIZE,sets))

f1_last = np.zeros((POP_SIZE,sets))
f2_last = np.zeros((POP_SIZE,sets))
f3_last = np.zeros((POP_SIZE,sets))

dataset_id = 1
for j in range(sets):
    for i in range(POP_SIZE):
        f1[i][j]= df['Power_first'][i+(j+dataset_id)*POP_SIZE]
        f2[i][j]= df['Num. Active Sensors_first'][i+(j+dataset_id)*POP_SIZE]
        f3[i][j]= df['Avg. Dist. to Sink node_first'][i+(j+dataset_id)*POP_SIZE]
        f1_last[i][j]= df['Power_last'][i+(j+dataset_id)*POP_SIZE]
        f2_last[i][j]= df['Num. Active Sensors_last'][i+(j+dataset_id)*POP_SIZE]
        f3_last[i][j]= df['Avg. Dist. to Sink node_last'][i+(j+dataset_id)*POP_SIZE]

mean_f1 = np.mean(f1, axis=1)
mean_f2 = np.mean(f2, axis=1)
mean_f3 = np.mean(f3, axis=1)

std_f1 = np.std(f1, axis=1)
std_f2 = np.std(f2, axis=1)
std_f3 = np.std(f3, axis=1)

mean_f1_last = np.mean(f1_last, axis=1)
mean_f2_last = np.mean(f2_last, axis=1)
mean_f3_last = np.mean(f3_last, axis=1)

std_f1_last = np.std(f1_last, axis=1)
std_f2_last = np.std(f2_last, axis=1)
std_f3_last = np.std(f3_last, axis=1)

# print(f1)

# merge the results to df
df_out = pd.DataFrame()
df_out['Power_first_mean'] = mean_f1
df_out['Power_first_std'] = std_f1
df_out['Num. Active Sensors_first_mean'] = mean_f2
df_out['Num. Active Sensors_first_std'] = std_f2
df_out['Avg. Dist. to Sink node_first_mean'] = mean_f3
df_out['Avg. Dist. to Sink node_first_std'] = std_f3
df_out['Power_last_mean'] = mean_f1_last
df_out['Power_last_std'] = std_f1_last
df_out['Num. Active Sensors_last_mean'] = mean_f2_last
df_out['Num. Active Sensors_last_std'] = std_f2_last
df_out['Avg. Dist. to Sink node_last_mean'] = mean_f3_last
df_out['Avg. Dist. to Sink node_last_std'] = std_f3_last
df_out.to_csv(f"Results/uniform/50x1000unit/100sensors/First_vs_last_solutions_mean_std_{datasets[dataset_id]}.csv")

# %%
# plot the result
import matplotlib.pyplot as plt
plt.errorbar(range(POP_SIZE), mean_f1, yerr=std_f1, fmt='o', label='Power_first')
plt.errorbar(range(POP_SIZE), mean_f1_last, yerr=std_f1_last, fmt='o', label='Power_last')
plt.xticks(range(POP_SIZE))  
plt.legend()
plt.show()

plt.errorbar(range(POP_SIZE), mean_f2, yerr=std_f2, fmt='o', label='Num. Active Sensors_first')
plt.errorbar(range(POP_SIZE), mean_f2_last, yerr=std_f2_last, fmt='o', label='Num. Active Sensors_last')
plt.xticks(range(POP_SIZE))  
plt.legend()
plt.show()

plt.errorbar(range(POP_SIZE), mean_f3, yerr=std_f3, fmt='o', label='Avg. Dist. to Sink node_first')
plt.errorbar(range(POP_SIZE), mean_f3_last, yerr=std_f3_last, fmt='o', label='Avg. Dist. to Sink node_last')
plt.xticks(range(POP_SIZE))  
plt.legend()
plt.show()
